# %%
import new_parser

# %%
new_parser.make_query('ophtalmologiste', '59000')
# Out:
#                                Nom  \
# 0                   CURAN  ANTOINE
# 1                   CURAN  ANTOINE
# 2             BARANZELLI  PHILIPPE
# 3                  DUMAS  STEPHANE
# 4                   DEWAVRIN  ERIC
# 5                SIGNOLLES  CLAUDE
# 6                SIGNOLLES  CLAUDE
# 7                   BORET  TRISTAN
# 8                     NOUVEL  LISA
# 9                SANTERRE  NICOLAS
# 10                 HOCHART  GILLES
# 11                  EVAIN  BERNARD
# 12               GRUNEWALD  FRANCK
# 13                VIEVILLE  CLAIRE
# 14                  MOUTON  DIDIER
# 15                  MOUTON  DIDIER
# 16         COILLIOT ROCQUE  JOELLE
# 17             DURET  MARIE HELENE
# 18             DURET  MARIE HELENE
# 19              BLANCHARD  SYLVAIN
# 20  PASQUESOONE POINSARD  CAROLINE
# 21                 CAILLIAU  DAVID
# 22              BENSOUSSAN  MAXIME
# 23              BENSOUSSAN  MAXIME
# 24                    DEMORY  ELSA
# ...

# %%
df = _2

# %%
df.Nom.unique().size
# Out:
# 41

# %%
df.insert(0, ['ophtalmo'] * df.shape[0], 'Specialty')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-7-68c132f0fd92> in <module>()
# ----> 1 df.insert(0, ['ophtalmo'] * df.shape[0], 'Specialty')
#
# C:\Anaconda\lib\site-packages\pandas\core\frame.pyc in insert(self, loc, column, value, allow_duplicates)
#    2209         """
#    2210         self._ensure_valid_index(value)
# -> 2211         value = self._sanitize_column(column, value)
#    2212         self._data.insert(
#    2213             loc, column, value, allow_duplicates=allow_duplicates)
#
# C:\Anaconda\lib\site-packages\pandas\core\frame.pyc in _sanitize_column(self, key, value)
#    2279
#    2280         # broadcast across multiple columns if necessary
# -> 2281         if key in self.columns and value.ndim == 1:
#    2282             if not self.columns.is_unique or isinstance(self.columns,
# ...
