# %%
def grayify_cmap(cmap):
    """Return a grayscale version of the colormap"""
    cmap = plt.cm.get_cmap(cmap)
    colors = cmap(np.arange(cmap.N))
    
    # convert RGBA to perceived greyscale luminance
    # cf. http://alienryderflex.com/hsp.html
    RGB_weight = [0.299, 0.587, 0.114]
    luminance = np.sqrt(np.dot(colors[:, :3] ** 2, RGB_weight))
    colors[:, :3] = luminance[:, np.newaxis]
    
    return cmap.from_list(cmap.name + "_grayscale", colors, cmap.N)

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt

x = np.linspace(0, 6)
y = np.linspace(0, 3)[:, np.newaxis]
z = 10 * np.cos(x ** 2) * np.exp(-y)

# %%
plt.imshow(z, cmap=grayify_cmap('jet'))
plt.colorbar();

# %%
plt.imshow(z, cmap=grayify_cmap('cubehelix'))
plt.colorbar();

# %%
plt.imshow(z, cmap='cubehelix')
plt.colorbar();

# %%
import civa_tools

# %%
plt.imshow(z, cmap=civa_tools.civa_cmap)
plt.colorbar();

# %%
plt.imshow(np.abs(z), cmap=civa_tools.civa_cmap)
plt.colorbar();

# %%
plt.imshow(z, cmap=grayify_cmap(civa_tools.civa_cmap))
plt.colorbar();

# %%
plt.imshow(np.abs(z), cmap=grayify_cmap(civa_tools.civa_cmap))
plt.colorbar();

# %%
from mayavi import mlab
# Out:
# WARNING:traits.has_traits:DEPRECATED: traits.has_traits.wrapped_class, 'the 'implements' class advisor has been deprecated. Use the 'provides' class decorator.

# %%
mlab.figure(1)
mlab.surf(z)

# %%
mlab.figure(2)
mlab.surf(z, colormap='jet')

# %%
# %gui wx
